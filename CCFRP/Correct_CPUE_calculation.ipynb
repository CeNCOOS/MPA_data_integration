# %% [markdown]
# # Notebook showing how to correctly calculate CPUE for CCFRP data

# %%
# Imports

import numpy as np
import pandas as pd

# %%
# Load data

occ = pd.read_csv('CCFRP_grid-level_occurrence.csv')
mof = pd.read_csv('CCFRP_grid-level_mof.csv', sep=',')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-b67c1a169964> in <module>
#       2
#       3 occ = pd.read_csv('CCFRP_grid-level_occurrence.csv')
# ----> 4 mof = pd.read_csv('CCFRP_grid-level_mof.csv', sep=',')
#
# ~\PycharmProjects\PythonScripts\venv\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~\PycharmProjects\PythonScripts\venv\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# ~\PycharmProjects\PythonScripts\venv\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# ~\PycharmProjects\PythonScripts\venv\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 4 fields in line 480633, saw 5

# %% [markdown]
# **Note** that I've now included an `organismQuantity` column in occ that contains CPUE for each species during each survey. This was previously only in the MoF file, requiring a merge to get it paired with other survey-level data.

# %%
occ.head()
# Out:
#        eventID   eventDate datasetID        locality        locationRemarks  \
# 0  AIM09082002  2020-09-08     CCFRP  Anacapa Island  marine protected area
# 1  AIM09082002  2020-09-08     CCFRP  Anacapa Island  marine protected area
# 2  AIM09082002  2020-09-08     CCFRP  Anacapa Island  marine protected area
# 3  AIM09082002  2020-09-08     CCFRP  Anacapa Island  marine protected area
# 4  AIM09082002  2020-09-08     CCFRP  Anacapa Island  marine protected area
#
#   countryCode                                       footprintWKT  \
# 0          US  POLYGON ((34.01885605 -119.3689897, 34.0219688...
# 1          US  POLYGON ((34.01885605 -119.3689897, 34.0219688...
# 2          US  POLYGON ((34.01885605 -119.3689897, 34.0219688...
# 3          US  POLYGON ((34.01885605 -119.3689897, 34.0219688...
# 4          US  POLYGON ((34.01885605 -119.3689897, 34.0219688...
#
#    decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  ...  \
# 0        34.020412       -119.372326                            354  ...
# 1        34.020412       -119.372326                            354  ...
# 2        34.020412       -119.372326                            354  ...
# 3        34.020412       -119.372326                            354  ...
# 4        34.020412       -119.372326                            354  ...
#
#            scientificName                           scientificNameID taxonID  \
# 0    Paralabrax nebulifer  urn:lsid:marinespecies.org:taxname:282059  282059
# 1  Myliobatis californica  urn:lsid:marinespecies.org:taxname:271485  271485
# 2   Hippoglossina stomata  urn:lsid:marinespecies.org:taxname:275827  275827
# 3    Sebastes chrysomelas  urn:lsid:marinespecies.org:taxname:240737  240737
# 4       Sebastes melanops  urn:lsid:marinespecies.org:taxname:274817  274817
#
#   nameAccordingTo  identificationQualifier occurrenceStatus     basisOfRecord  \
# 0           WoRMS                      NaN           absent  HumanObservation
# 1           WoRMS                      NaN           absent  HumanObservation
# 2           WoRMS                      NaN           absent  HumanObservation
# 3           WoRMS                      NaN           absent  HumanObservation
# 4           WoRMS                      NaN           absent  HumanObservation
#
#   individualCount organismQuantity  \
# 0               0              0.0
# 1               0              0.0
# 2               0              0.0
# 3               0              0.0
# 4               0              0.0
#
#                                 organismQuantityType
# 0  Catch-Per-Unit-Effort in number of fishes caug...
# 1  Catch-Per-Unit-Effort in number of fishes caug...
# 2  Catch-Per-Unit-Effort in number of fishes caug...
# 3  Catch-Per-Unit-Effort in number of fishes caug...
# 4  Catch-Per-Unit-Effort in number of fishes caug...
#
# [5 rows x 22 columns]

# %% [markdown]
# In this data set `eventID` contains all the information about when and where a survey was done (site code, date, grid cell number). You'll see that for each survey, the number caught of 93 different species of fish is recorded.

# %%
## 93 fish species were looked for per survey

num_sp_looked_for = occ.groupby('eventID')['scientificName'].count()
any(num_sp_looked_for != 93)
# Out:
# False

# %%
## Here they are

occ['scientificName'].unique()
# Out:
# array(['Paralabrax nebulifer', 'Myliobatis californica',
#        'Hippoglossina stomata', 'Sebastes chrysomelas',
#        'Sebastes melanops', 'Chromis punctipinnis', 'Sebastes mystinus',
#        'Sebastes paucispinis', 'Sebastes auriculatus', 'Enophrys bison',
#        'Enophrys taurina', 'Scorpaenichthys marmoratus', 'Sebastes dalli',
#        'Paralichthys californicus', 'Synodus lucioceps',
#        'Scorpaena guttata', 'Semicossyphus pulcher', 'Sebastes pinniger',
#        'Sebastes goodei', 'Sebastes nebulosus',
#        'Oncorhynchus tshawytscha', 'Alopias vulpinus',
#        'Sebastes caurinus', 'Sebastes diaconus', 'Xystreurys liolepis',
#        'Sebastes lentiginosus', 'Hypsypops rubicundus',
#        'Stereolepis gigas', 'Sebastes carnatus', 'Sebastes rastrelliger',
#        'Medialuna californiensis', 'Sebastes umbrosus',
#        'Trachurus symmetricus', 'Atherinopsis californiensis',
#        'Paralabrax clathratus', 'Hexagrammos decagrammus',
#        'Sebastes atrovirens', 'Ophiodon elongatus',
#        'Citharichthys xanthostigma', 'Scombridae', 'Engraulis mordax',
#        'Caulolatilus princeps', 'Sebastes', 'Sebastes serranoides',
#        'Girella nigricans', 'Scomber japonicus', 'Sphyraena argentea',
#        'Sarda chiliensis', 'Hippoglossus stenolepis',
#        'Citharichthys sordidus', 'Sardinops sagax', 'Oxylebius pictus',
#        'Pteroplatytrygon violacea', 'Eopsetta jordani',
#        'Rhacochilus vacca', 'Sebastes maliger',
#        'Hexagrammos lagocephalus', 'Lepidopsetta bilineata',
#        'Halichoeres semicinctus', 'Sebastes rosaceus',
#        'Rhacochilus toxotes', 'Xenistius californiensis',
#        'Psettichthys melanostictus', 'Citharichthys',
#        'Neoclinus blanchardi', 'Anisotremus davidsonii',
#        'Artedius harringtoni', 'Oxyjulis californica',
#        'Phanerodon atripes', 'Atherinopsidae', 'Galeorhinus galeus',
#        'Citharichthys stigmaeus', 'Squalus acanthias',
#        'Sebastes hopkinsi', 'Sebastes constellatus',
#        'Beringraja stellulata', 'Embiotoca lateralis',
#        'Sebastes nigrocinctus', 'Atherinops affinis',
#        'Sebastes serriceps', 'Aulorhynchus flavidus', 'Pisces',
#        'Sebastes miniatus', 'Genyonemus lineatus', 'Atractoscion nobilis',
#        'Sebastes entomelas', 'Anarrhichthys ocellatus',
#        'Sebastes ruberrimus', 'Umbrina roncador', 'Seriola lalandi',
#        'Sebastes flavidus'], dtype=object)

# %% [markdown]
# **Note** that this list contains only 91 names. There are two rows in each survey where `scientificName` = Sebastes and Sebastes mystinus due to uncertainty in naming categories in the original data (e.g. when a fish could have been either S. serranoides or S. flavidus, that gets generalized to Sebastes).
#
# ```python
# occ[(occ['eventID'] == 'AIM09082002') & (occ['scientificName'] == 'Sebastes mystinus')]
# ```

# %%
## Calculate CPUE for one survey

occ.loc[occ['eventID'] == 'AIM09082002', 'organismQuantity'].sum()
# Out:
# 23.190184048000003

# %%
## For all surveys

occ.groupby('eventID', as_index=False)['organismQuantity'].sum()
# Out:
#           eventID  organismQuantity
# 0     AIM09082002         23.190184
# 1     AIM09082006         16.408163
# 2     AIM09102005         21.333333
# 3     AIM09102008          7.272727
# 4     AIM09152001         18.981233
# ...           ...               ...
# 2408  TMR09061721          2.000000
# 2409  TMR10311702          5.666667
# 2410  TMR10311713          8.426966
# 2411  TMR10311722         17.865169
# 2412  TMR10311723          9.050279
#
# [2413 rows x 2 columns]

# %%
## So that we can see the place, date, etc. separated out

cpue = occ.groupby(['eventID', 'locality', 'locationRemarks'], as_index=False)['organismQuantity'].sum()
cpue['year'] = cpue['eventID'].str[7:9]
cpue['gridCellID'] = cpue['eventID'].str[9:]
cpue
# Out:
#           eventID        locality        locationRemarks  organismQuantity  \
# 0     AIM09082002  Anacapa Island  marine protected area         23.190184
# 1     AIM09082006  Anacapa Island  marine protected area         16.408163
# 2     AIM09102005  Anacapa Island  marine protected area         21.333333
# 3     AIM09102008  Anacapa Island  marine protected area          7.272727
# 4     AIM09152001  Anacapa Island  marine protected area         18.981233
# ...           ...             ...                    ...               ...
# 2408  TMR09061721        Ten Mile            fished area          2.000000
# 2409  TMR10311702        Ten Mile            fished area          5.666667
# 2410  TMR10311713        Ten Mile            fished area          8.426966
# 2411  TMR10311722        Ten Mile            fished area         17.865169
# 2412  TMR10311723        Ten Mile            fished area          9.050279
#
#      year gridCellID
# 0      20         02
# 1      20         06
# 2      20         05
# 3      20         08
# 4      20         01
# ...   ...        ...
# 2408   17         21
# 2409   17         02
# 2410   17         13
# 2411   17         22
# 2412   17         23
#
# [2413 rows x 6 columns]

# %%
cpue[(cpue['locality'] == 'Anacapa Island') & (cpue['year'] == '19')]
# Out:
#         eventID        locality        locationRemarks  organismQuantity year  \
# 8   AIM09171903  Anacapa Island  marine protected area         22.044728   19
# 9   AIM09171904  Anacapa Island  marine protected area         18.036810   19
# 12  AIM09181901  Anacapa Island  marine protected area         21.391304   19
# 13  AIM09181905  Anacapa Island  marine protected area         23.147793   19
# 14  AIM09181907  Anacapa Island  marine protected area         10.337838   19
# 15  AIM09191901  Anacapa Island  marine protected area         20.055249   19
# 16  AIM09191906  Anacapa Island  marine protected area          2.818792   19
# 19  AIM10091905  Anacapa Island  marine protected area         22.008197   19
# 20  AIM10091909  Anacapa Island  marine protected area          6.230769   19
# 23  AIM10231904  Anacapa Island  marine protected area         16.704197   19
# 24  AIM10231908  Anacapa Island  marine protected area          8.829916   19
# 45  AIR09171910  Anacapa Island            fished area          3.529412   19
# 46  AIR09171913  Anacapa Island            fished area          5.129225   19
# 49  AIR09181911  Anacapa Island            fished area          1.960428   19
# 50  AIR09181917  Anacapa Island            fished area          6.113312   19
# 51  AIR09191912  Anacapa Island            fished area          4.186047   19
# 52  AIR09191915  Anacapa Island            fished area          1.777778   19
# 55  AIR10091914  Anacapa Island            fished area          3.129496   19
# 56  AIR10091916  Anacapa Island            fished area          4.114286   19
# 59  AIR10231910  Anacapa Island            fished area          3.983903   19
# 60  AIR10231916  Anacapa Island            fished area          3.861386   19
#
#    gridCellID
# 8          03
# 9          04
# 12         01
# 13         05
# 14         07
# 15         01
# 16         06
# 19         05
# 20         09
# 23         04
# 24         08
# 45         10
# 46         13
# 49         11
# 50         17
# 51         12
# 52         15
# 55         14
# 56         16
# 59         10
# 60         16

# %%
cpue_mapper = occ.groupby(['eventID', 'locality', 'locationRemarks'], as_index=False)['organismQuantity'].mean()
cpue_mapper['year'] = cpue_mapper['eventID'].str[7:9]
cpue_mapper['gridCellID'] = cpue_mapper['eventID'].str[9:]
cpue_mapper
# Out:
#           eventID        locality        locationRemarks  organismQuantity  \
# 0     AIM09082002  Anacapa Island  marine protected area          0.249357
# 1     AIM09082006  Anacapa Island  marine protected area          0.176432
# 2     AIM09102005  Anacapa Island  marine protected area          0.229391
# 3     AIM09102008  Anacapa Island  marine protected area          0.078201
# 4     AIM09152001  Anacapa Island  marine protected area          0.204099
# ...           ...             ...                    ...               ...
# 2408  TMR09061721        Ten Mile            fished area          0.021505
# 2409  TMR10311702        Ten Mile            fished area          0.060932
# 2410  TMR10311713        Ten Mile            fished area          0.090613
# 2411  TMR10311722        Ten Mile            fished area          0.192099
# 2412  TMR10311723        Ten Mile            fished area          0.097315
#
#      year gridCellID
# 0      20         02
# 1      20         06
# 2      20         05
# 3      20         08
# 4      20         01
# ...   ...        ...
# 2408   17         21
# 2409   17         02
# 2410   17         13
# 2411   17         22
# 2412   17         23
#
# [2413 rows x 6 columns]

# %%
cpue_mapper[(cpue_mapper['locality'] == 'Anacapa Island') & (cpue_mapper['year'] == '19')]
# Out:
#         eventID        locality        locationRemarks  organismQuantity year  \
# 8   AIM09171903  Anacapa Island  marine protected area          0.237040   19
# 9   AIM09171904  Anacapa Island  marine protected area          0.193944   19
# 12  AIM09181901  Anacapa Island  marine protected area          0.230014   19
# 13  AIM09181905  Anacapa Island  marine protected area          0.248901   19
# 14  AIM09181907  Anacapa Island  marine protected area          0.111160   19
# 15  AIM09191901  Anacapa Island  marine protected area          0.215648   19
# 16  AIM09191906  Anacapa Island  marine protected area          0.030310   19
# 19  AIM10091905  Anacapa Island  marine protected area          0.236647   19
# 20  AIM10091909  Anacapa Island  marine protected area          0.066998   19
# 23  AIM10231904  Anacapa Island  marine protected area          0.179615   19
# 24  AIM10231908  Anacapa Island  marine protected area          0.094945   19
# 45  AIR09171910  Anacapa Island            fished area          0.037951   19
# 46  AIR09171913  Anacapa Island            fished area          0.055153   19
# 49  AIR09181911  Anacapa Island            fished area          0.021080   19
# 50  AIR09181917  Anacapa Island            fished area          0.065735   19
# 51  AIR09191912  Anacapa Island            fished area          0.045011   19
# 52  AIR09191915  Anacapa Island            fished area          0.019116   19
# 55  AIR10091914  Anacapa Island            fished area          0.033650   19
# 56  AIR10091916  Anacapa Island            fished area          0.044240   19
# 59  AIR10231910  Anacapa Island            fished area          0.042838   19
# 60  AIR10231916  Anacapa Island            fished area          0.041520   19
#
#    gridCellID
# 8          03
# 9          04
# 12         01
# 13         05
# 14         07
# 15         01
# 16         06
# 19         05
# 20         09
# 23         04
# 24         08
# 45         10
# 46         13
# 49         11
# 50         17
# 51         12
# 52         15
# 55         14
# 56         16
# 59         10
# 60         16

# %%
## But in the mapper 

test = occ[(occ['locality'] == 'Anacapa Island') & 
    (occ['locationRemarks'] == 'marine protected area') & 
    (occ['eventDate'] > '2019-01-01') &
    (occ['eventDate'] < '2019-12-31') &
    (occ['decimalLatitude'] == 34.01169968)
          ]

test
# Out:
#           eventID   eventDate datasetID        locality  \
# 837   AIM09171904  2019-09-17     CCFRP  Anacapa Island
# 838   AIM09171904  2019-09-17     CCFRP  Anacapa Island
# 839   AIM09171904  2019-09-17     CCFRP  Anacapa Island
# 840   AIM09171904  2019-09-17     CCFRP  Anacapa Island
# 841   AIM09171904  2019-09-17     CCFRP  Anacapa Island
# ...           ...         ...       ...             ...
# 2227  AIM10231904  2019-10-23     CCFRP  Anacapa Island
# 2228  AIM10231904  2019-10-23     CCFRP  Anacapa Island
# 2229  AIM10231904  2019-10-23     CCFRP  Anacapa Island
# 2230  AIM10231904  2019-10-23     CCFRP  Anacapa Island
# 2231  AIM10231904  2019-10-23     CCFRP  Anacapa Island
#
#             locationRemarks countryCode  \
# 837   marine protected area          US
# 838   marine protected area          US
# 839   marine protected area          US
# 840   marine protected area          US
# 841   marine protected area          US
# ...                     ...         ...
# 2227  marine protected area          US
# 2228  marine protected area          US
# 2229  marine protected area          US
# 2230  marine protected area          US
# 2231  marine protected area          US
#
#                                            footprintWKT  decimalLatitude  \
# 837   POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 838   POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 839   POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 840   POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 841   POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# ...                                                 ...              ...
# 2227  POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 2228  POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 2229  POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 2230  POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 2231  POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
#
#       decimalLongitude  coordinateUncertaintyInMeters  ...  \
# 837        -119.392358                            354  ...
# 838        -119.392358                            354  ...
# 839        -119.392358                            354  ...
# 840        -119.392358                            354  ...
# 841        -119.392358                            354  ...
# ...                ...                            ...  ...
# 2227       -119.392358                            354  ...
# 2228       -119.392358                            354  ...
# 2229       -119.392358                            354  ...
# 2230       -119.392358                            354  ...
# 2231       -119.392358                            354  ...
#
#                scientificName                           scientificNameID  \
# 837      Paralabrax nebulifer  urn:lsid:marinespecies.org:taxname:282059
# 838    Myliobatis californica  urn:lsid:marinespecies.org:taxname:271485
# 839     Hippoglossina stomata  urn:lsid:marinespecies.org:taxname:275827
# 840      Sebastes chrysomelas  urn:lsid:marinespecies.org:taxname:240737
# 841         Sebastes melanops  urn:lsid:marinespecies.org:taxname:274817
# ...                       ...                                        ...
# 2227  Anarrhichthys ocellatus  urn:lsid:marinespecies.org:taxname:279605
# 2228      Sebastes ruberrimus  urn:lsid:marinespecies.org:taxname:274844
# 2229         Umbrina roncador  urn:lsid:marinespecies.org:taxname:273802
# 2230          Seriola lalandi  urn:lsid:marinespecies.org:taxname:218436
# 2231        Sebastes flavidus  urn:lsid:marinespecies.org:taxname:274795
#
#      taxonID nameAccordingTo  identificationQualifier occurrenceStatus  \
# 837   282059           WoRMS                      NaN           absent
# 838   271485           WoRMS                      NaN           absent
# 839   275827           WoRMS                      NaN           absent
# 840   240737           WoRMS                      NaN           absent
# 841   274817           WoRMS                      NaN           absent
# ...      ...             ...                      ...              ...
# 2227  279605           WoRMS                      NaN           absent
# 2228  274844           WoRMS                      NaN           absent
# 2229  273802           WoRMS                      NaN           absent
# 2230  218436           WoRMS                      NaN           absent
# 2231  274795           WoRMS                      NaN           absent
#
#          basisOfRecord individualCount organismQuantity  \
# 837   HumanObservation               0              0.0
# 838   HumanObservation               0              0.0
# 839   HumanObservation               0              0.0
# 840   HumanObservation               0              0.0
# 841   HumanObservation               0              0.0
# ...                ...             ...              ...
# 2227  HumanObservation               0              0.0
# 2228  HumanObservation               0              0.0
# 2229  HumanObservation               0              0.0
# 2230  HumanObservation               0              0.0
# 2231  HumanObservation               0              0.0
#
#                                    organismQuantityType
# 837   Catch-Per-Unit-Effort in number of fishes caug...
# 838   Catch-Per-Unit-Effort in number of fishes caug...
# 839   Catch-Per-Unit-Effort in number of fishes caug...
# 840   Catch-Per-Unit-Effort in number of fishes caug...
# 841   Catch-Per-Unit-Effort in number of fishes caug...
# ...                                                 ...
# 2227  Catch-Per-Unit-Effort in number of fishes caug...
# 2228  Catch-Per-Unit-Effort in number of fishes caug...
# 2229  Catch-Per-Unit-Effort in number of fishes caug...
# 2230  Catch-Per-Unit-Effort in number of fishes caug...
# 2231  Catch-Per-Unit-Effort in number of fishes caug...
#
# [186 rows x 22 columns]

# %%
d = test[test['eventDate'] == '2019-09-17']
d
# Out:
#          eventID   eventDate datasetID        locality        locationRemarks  \
# 837  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 838  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 839  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 840  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 841  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# ..           ...         ...       ...             ...                    ...
# 925  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 926  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 927  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 928  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 929  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
#
#     countryCode                                       footprintWKT  \
# 837          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 838          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 839          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 840          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 841          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# ..          ...                                                ...
# 925          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 926          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 927          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 928          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 929          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
#
#      decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  ...  \
# 837          34.0117       -119.392358                            354  ...
# 838          34.0117       -119.392358                            354  ...
# 839          34.0117       -119.392358                            354  ...
# 840          34.0117       -119.392358                            354  ...
# 841          34.0117       -119.392358                            354  ...
# ..               ...               ...                            ...  ...
# 925          34.0117       -119.392358                            354  ...
# 926          34.0117       -119.392358                            354  ...
# 927          34.0117       -119.392358                            354  ...
# 928          34.0117       -119.392358                            354  ...
# 929          34.0117       -119.392358                            354  ...
#
#               scientificName                           scientificNameID  \
# 837     Paralabrax nebulifer  urn:lsid:marinespecies.org:taxname:282059
# 838   Myliobatis californica  urn:lsid:marinespecies.org:taxname:271485
# 839    Hippoglossina stomata  urn:lsid:marinespecies.org:taxname:275827
# 840     Sebastes chrysomelas  urn:lsid:marinespecies.org:taxname:240737
# 841        Sebastes melanops  urn:lsid:marinespecies.org:taxname:274817
# ..                       ...                                        ...
# 925  Anarrhichthys ocellatus  urn:lsid:marinespecies.org:taxname:279605
# 926      Sebastes ruberrimus  urn:lsid:marinespecies.org:taxname:274844
# 927         Umbrina roncador  urn:lsid:marinespecies.org:taxname:273802
# 928          Seriola lalandi  urn:lsid:marinespecies.org:taxname:218436
# 929        Sebastes flavidus  urn:lsid:marinespecies.org:taxname:274795
#
#     taxonID nameAccordingTo  identificationQualifier occurrenceStatus  \
# 837  282059           WoRMS                      NaN           absent
# 838  271485           WoRMS                      NaN           absent
# 839  275827           WoRMS                      NaN           absent
# 840  240737           WoRMS                      NaN           absent
# 841  274817           WoRMS                      NaN           absent
# ..      ...             ...                      ...              ...
# 925  279605           WoRMS                      NaN           absent
# 926  274844           WoRMS                      NaN           absent
# 927  273802           WoRMS                      NaN           absent
# 928  218436           WoRMS                      NaN           absent
# 929  274795           WoRMS                      NaN           absent
#
#         basisOfRecord individualCount organismQuantity  \
# 837  HumanObservation               0              0.0
# 838  HumanObservation               0              0.0
# 839  HumanObservation               0              0.0
# 840  HumanObservation               0              0.0
# 841  HumanObservation               0              0.0
# ..                ...             ...              ...
# 925  HumanObservation               0              0.0
# 926  HumanObservation               0              0.0
# 927  HumanObservation               0              0.0
# 928  HumanObservation               0              0.0
# 929  HumanObservation               0              0.0
#
#                                   organismQuantityType
# 837  Catch-Per-Unit-Effort in number of fishes caug...
# 838  Catch-Per-Unit-Effort in number of fishes caug...
# 839  Catch-Per-Unit-Effort in number of fishes caug...
# 840  Catch-Per-Unit-Effort in number of fishes caug...
# 841  Catch-Per-Unit-Effort in number of fishes caug...
# ..                                                 ...
# 925  Catch-Per-Unit-Effort in number of fishes caug...
# 926  Catch-Per-Unit-Effort in number of fishes caug...
# 927  Catch-Per-Unit-Effort in number of fishes caug...
# 928  Catch-Per-Unit-Effort in number of fishes caug...
# 929  Catch-Per-Unit-Effort in number of fishes caug...
#
# [93 rows x 22 columns]

# %%
d['organismQuantity'].mean()
# Out:
# 0.19394419156989248

# %%
d['organismQuantity'].sum()
# Out:
# 18.036809816

# %%
d['organismQuantity'].max()
# Out:
# 14.72392638

# %%
d['organismQuantity'].min()
# Out:
# 0.0

# %%
not_zero = d[d['organismQuantity'] > 0]
not_zero
# Out:
#          eventID   eventDate datasetID        locality        locationRemarks  \
# 853  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 867  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 871  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
# 878  AIM09171904  2019-09-17     CCFRP  Anacapa Island  marine protected area
#
#     countryCode                                       footprintWKT  \
# 853          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 867          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 871          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
# 878          US  POLYGON ((34.01392365 -119.38961, 34.00950241 ...
#
#      decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  ...  \
# 853          34.0117       -119.392358                            354  ...
# 867          34.0117       -119.392358                            354  ...
# 871          34.0117       -119.392358                            354  ...
# 878          34.0117       -119.392358                            354  ...
#
#                scientificName                           scientificNameID  \
# 853     Semicossyphus pulcher  urn:lsid:marinespecies.org:taxname:282753
# 867  Medialuna californiensis  urn:lsid:marinespecies.org:taxname:281541
# 871     Paralabrax clathratus  urn:lsid:marinespecies.org:taxname:282054
# 878     Caulolatilus princeps  urn:lsid:marinespecies.org:taxname:276217
#
#     taxonID nameAccordingTo  identificationQualifier occurrenceStatus  \
# 853  282753           WoRMS                      NaN          present
# 867  281541           WoRMS                      NaN          present
# 871  282054           WoRMS                      NaN          present
# 878  276217           WoRMS                      NaN          present
#
#         basisOfRecord individualCount organismQuantity  \
# 853  HumanObservation               3         0.552147
# 867  HumanObservation               1         0.184049
# 871  HumanObservation              14         2.576687
# 878  HumanObservation              80        14.723926
#
#                                   organismQuantityType
# 853  Catch-Per-Unit-Effort in number of fishes caug...
# 867  Catch-Per-Unit-Effort in number of fishes caug...
# 871  Catch-Per-Unit-Effort in number of fishes caug...
# 878  Catch-Per-Unit-Effort in number of fishes caug...
#
# [4 rows x 22 columns]

# %%
not_zero['organismQuantity'].min()
# Out:
# 0.18404908

# %%
not_zero['organismQuantity'].mean()
# Out:
# 4.509202454

# %%
test[test['scientificName'] == 'Caulolatilus princeps']
# Out:
#           eventID   eventDate datasetID        locality  \
# 878   AIM09171904  2019-09-17     CCFRP  Anacapa Island
# 2180  AIM10231904  2019-10-23     CCFRP  Anacapa Island
#
#             locationRemarks countryCode  \
# 878   marine protected area          US
# 2180  marine protected area          US
#
#                                            footprintWKT  decimalLatitude  \
# 878   POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
# 2180  POLYGON ((34.01392365 -119.38961, 34.00950241 ...          34.0117
#
#       decimalLongitude  coordinateUncertaintyInMeters  ...  \
# 878        -119.392358                            354  ...
# 2180       -119.392358                            354  ...
#
#              scientificName                           scientificNameID  \
# 878   Caulolatilus princeps  urn:lsid:marinespecies.org:taxname:276217
# 2180  Caulolatilus princeps  urn:lsid:marinespecies.org:taxname:276217
#
#      taxonID nameAccordingTo  identificationQualifier occurrenceStatus  \
# 878   276217           WoRMS                      NaN          present
# 2180  276217           WoRMS                      NaN          present
#
#          basisOfRecord individualCount organismQuantity  \
# 878   HumanObservation              80        14.723926
# 2180  HumanObservation             116        14.247697
#
#                                    organismQuantityType
# 878   Catch-Per-Unit-Effort in number of fishes caug...
# 2180  Catch-Per-Unit-Effort in number of fishes caug...
#
# [2 rows x 22 columns]

# %%
116+80
# Out:
# 196
