# %% [markdown]
# # MARINe: Phototransect conversion
#
# MARINe conducts long-term monitoring at sites along the coast of North America approximately annually. Permanent photoplots are employed to monitor the cover of target species assemblages
# representing different intertidal zones. Plots are established at sites with sufficient
# cover of the target species. The cover of the target species is estimated by sampling 5 permanent 50x75 cm (0.375 m) plots and scoring point contact occurrences by superimposing a uniform grid of 100 dots on the resulting image.
#
# Additionally, permanent point-intercept transects are employed to monitor the cover of Phyllospadix scouleri/torreyi, Egregia menziezii, and Red Algae (turf algae, including articulated corallines and other red algae) at sites with sufficient cover of the relevant species. The cover of the target species is estimated by scoring occurrences at 100 points spaced at 10 cm intervals along 3, 10 m, permanent transects.
#
# **Resources:**
# - https://data.piscoweb.org/metacatui/view/doi:10.6085/AA/marine_ltm.12.4

# %%
## Import packages

import pandas as pd
import numpy as np
from datetime import datetime

import pyworms

from SPARQLWrapper import SPARQLWrapper, JSON

# %% [markdown]
# ## Load data

# %%
## Load data

data = pd.read_csv('phototransummarysd_download.csv')
print(data.shape)
data.head()
# Out:
# (262623, 25)
#   group_code marine_site_name site_code   latitude  longitude  \
# 0       CSUF     Crystal Cove      CRCO  33.570782 -117.83773
# 1       CSUF     Crystal Cove      CRCO  33.570782 -117.83773
# 2       CSUF     Crystal Cove      CRCO  33.570782 -117.83773
# 3       CSUF     Crystal Cove      CRCO  33.570782 -117.83773
# 4       CSUF     Crystal Cove      CRCO  33.570782 -117.83773
#
#    marine_sort_order  marine_common_year season_name marine_season_code  \
# 0               6660                2002        Fall               FA02
# 1               6660                2002        Fall               FA02
# 2               6660                2002        Fall               FA02
# 3               6660                2002        Fall               FA02
# 4               6660                2002        Fall               FA02
#
#    marine_common_season  ... num_plots_sampled      stdev    stderr  \
# 0                    87  ...                 5   3.130495  1.400000
# 1                    87  ...                 5   3.130495  1.400000
# 2                    87  ...                 5   0.000000  0.000000
# 3                    87  ...                 5   0.000000  0.000000
# 4                    87  ...                 5  14.124447  6.316645
#
#   state_province  georegion                   bioregion  mpa_designation  \
# 0     California   CA South  Government Point to Mexico             SMCA
# 1     California   CA South  Government Point to Mexico             SMCA
# 2     California   CA South  Government Point to Mexico             SMCA
# 3     California   CA South  Government Point to Mexico             SMCA
# 4     California   CA South  Government Point to Mexico             SMCA
#
#     mpa_region    island         last_updated
# 0  South Coast  Mainland  2021-03-26 10:55:59
# 1  South Coast  Mainland  2021-03-26 10:55:59
# 2  South Coast  Mainland  2021-03-26 10:55:59
# 3  South Coast  Mainland  2021-03-26 10:55:59
# 4  South Coast  Mainland  2021-03-26 10:55:59
#
# [5 rows x 25 columns]

# %%
## Site table

site = pd.read_csv('MARINe_site_table.txt')
print(site.shape)
site.head()
# Out:
# (269, 17)
#    marine_sort_order site_code marine_site_name                 county  \
# 0               1500       GRA    Graves Harbor  Skagway-Hoonah-Angoon
# 1               1600       YAK           Yakobi  Skagway-Hoonah-Angoon
# 2               1700       PMA        Port Mary                  Sitka
# 3               1720      SAGE        Sage Rock                  Sitka
# 4               1730       KAY     Kayak Island                  Sitka
#
#      island state_province        country   latitude  longitude pisco_code  \
# 0  Mainland         Alaska  United States  58.270821 -136.73148     IGHAXX
# 1    Yakobi         Alaska  United States  58.081501 -136.55453     IYAKXX
# 2   Kruzoff         Alaska  United States  57.154228 -135.75452     IPMAXX
# 3  Baranoff         Alaska  United States  57.048698 -135.32314     ISAGXX
# 4     Kayak         Alaska  United States  57.022499 -135.35387     IKAYXX
#
#   mpa_region mpa_lt_region mpa_designation mpa_name LTM_project_short_code  \
# 0        NaN           NaN             NaN      NaN                    NaN
# 1        NaN           NaN             NaN      NaN                    NaN
# 2        NaN           NaN             NaN      NaN                    NaN
# 3        NaN           NaN             NaN      NaN                    NaN
# 4        NaN           NaN             NaN      NaN                    NaN
#
#   georegion                   bioregion
# 0        AK  Alaska to British Columbia
# 1        AK  Alaska to British Columbia
# 2        AK  Alaska to British Columbia
# 3        AK  Alaska to British Columbia
# 4        AK  Alaska to British Columbia

# %%
## Species table

species = pd.read_csv('MARINe_species_table.txt')
print(species.shape)
species.head()
# Out:
# (50, 12)
#   lumping_code                          marine_species_name  \
# 0       ANTELE  anthopleura elegantissima; anthopleura sola
# 1       ARTCOR                       articulated corallines
# 2       BARNAC                                    barnacles
# 3       CHITON                                      chitons
# 4       CHOCAN                 chondracanthus canaliculatus
#
#                            marine_species_definition  taxonomic_id  \
# 0  anthopleura elegantissima/sola; may also inclu...      100696.0
# 1  erect; jointed; calcified; red algae of the Fa...      143691.0
# 2  any species of barnacle; used for transects wh...      106033.0
# 3                              any species of chiton          55.0
# 4                       chondracanthus canaliculatus      371723.0
#
#                                     taxonomic_source    kingdom  \
# 0  World Register of Marine Species:  www.marines...  Animalia
# 1  World Register of Marine Species:  www.marines...   Plantae
# 2  World Register of Marine Species:  www.marines...  Animalia
# 3  World Register of Marine Species:  www.marines...  Animalia
# 4  World Register of Marine Species:  www.marines...   Plantae
#
#                   phylum             class          order          family  \
# 0              Cnidaria          Anthozoa     Actiniaria      Actiniidae
# 1  (Division) Rhodophyta  Florideophyceae   Corallinales   Corallinaceae
# 2            Arthropoda       Thecostraca       Sessilia            NULL
# 3              Mollusca    Polyplacophora           NULL            NULL
# 4  (Division) Rhodophyta  Florideophyceae   Gigartinales   Gigartinaceae
#
#              genus                       species
# 0     Anthopleura                          NULL
# 1            NULL                          NULL
# 2            NULL                          NULL
# 3            NULL                          NULL
# 4  Chondracanthus   Chondracanthus canaliculatus

# %% [markdown]
# ## Conversion
#
# I'll define an event can as a survey, uniquely defined by the site code, min date, max date.
#
# An occurrence can be defined as a percent cover measurement of a species observed during the event. (I.e., if percent cover is greater than 0, at least 1 organism was observed, and the species is present).
#
# Measurements only pertain to occurrences, so I don't need a separate event file.

# %%
## eventID

occ = pd.DataFrame({'eventID':data['site_code'] + '_' + data['min_survey_date'] + '_' + data['max_survey_date']})
print(occ.shape)
occ.head()
# Out:
# (262623, 1)
#                       eventID
# 0  CRCO_2002-12-06_2002-12-06
# 1  CRCO_2002-12-06_2002-12-06
# 2  CRCO_2002-12-06_2002-12-06
# 3  CRCO_2002-12-06_2002-12-06
# 4  CRCO_2002-12-06_2002-12-06

# %%
## eventDate

occ['eventDate'] = data['min_survey_date'] + '/' + data['max_survey_date']
occ.head()
# Out:
#                       eventID              eventDate
# 0  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 1  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 2  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 3  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 4  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06

# %%
## datasetID

occ['datasetID'] = 'MARINe LTM - percent cover from photoplots and phototransects'
occ.head()
# Out:
#                       eventID              eventDate  \
# 0  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 1  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 2  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 3  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 4  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
#
#                                            datasetID
# 0  MARINe LTM - percent cover from photoplots and...
# 1  MARINe LTM - percent cover from photoplots and...
# 2  MARINe LTM - percent cover from photoplots and...
# 3  MARINe LTM - percent cover from photoplots and...
# 4  MARINe LTM - percent cover from photoplots and...

# %%
## Merge with site table to get locality, county, stateProvince, countryCode, decimalLat, decimalLon

# Add site code to occ
occ['site_code'] = data['site_code']

# Define columns to merge from site table
site_cols = [
    'site_code',
    'marine_site_name',
    'county',
    'state_province',
    'country',
    'latitude',
    'longitude',
]

# Define DwC terms for these columns after merge
dwc_cols = [
    'eventID',
    'eventDate',
    'datasetID',
    'locality',
    'county',
    'stateProvince',
    'countryCode',
    'decimalLatitude',
    'decimalLongitude',
]

# Merge
occ = occ.merge(site[site_cols], how='left', on='site_code')
occ.drop(columns=['site_code'], inplace=True)
occ.columns = dwc_cols
print(occ.shape)
occ.head()
# Out:
# (262623, 9)
#                       eventID              eventDate  \
# 0  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 1  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 2  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 3  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 4  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
#
#                                            datasetID      locality  county  \
# 0  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 1  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 2  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 3  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 4  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
#
#   stateProvince    countryCode  decimalLatitude  decimalLongitude
# 0    California  United States        33.570782        -117.83773
# 1    California  United States        33.570782        -117.83773
# 2    California  United States        33.570782        -117.83773
# 3    California  United States        33.570782        -117.83773
# 4    California  United States        33.570782        -117.83773

# %%
## Check county names against GTGN

# Define sql strings
counties_query = """
    select distinct * {
        # ?place skos:inScheme tgn: ;
        gvp:placeTypePreferred [gvp:prefLabelGVP [xl:literalForm ?type]];
        gvp:placeType|(gvp:placeType/gvp:broaderGenericExtended) [rdfs:label "counties"@en];
        gvp:broaderPartitiveExtended [rdfs:label "United States"@en];
        gvp:prefLabelGVP [xl:literalForm ?name];
        gvp:parentString ?parents}
"""

divisions_query = """
    select distinct * {
        # ?place skos:inScheme tgn: ;
        gvp:placeTypePreferred [gvp:prefLabelGVP [xl:literalForm ?type]];
        gvp:placeType|(gvp:placeType/gvp:broaderGenericExtended) [rdfs:label "national divisions"@en];
        gvp:broaderPartitiveExtended [rdfs:label "United States"@en];
        gvp:prefLabelGVP [xl:literalForm ?name];
        gvp:parentString ?parents}
"""

# Set up query
sparql = SPARQLWrapper("http://vocab.getty.edu/sparql")
sparql.setReturnFormat(JSON)
sparql.setQuery(counties_query)

# Obtain county results
try:
   counties_ret = sparql.query().convert()
except e:
   print(e)

# Obtain national division results (Alaska has boroughs and census districts, not counties)
sparql.setQuery(divisions_query)
try:
   div_ret = sparql.query().convert()
except e:
   print(e)

# %%
## Clean result

# Extract into data frame
county_df = pd.DataFrame(counties_ret['results']['bindings'])
county_df = county_df.applymap(lambda x: x['value'])
div_df = pd.DataFrame(div_ret['results']['bindings'])
div_df = div_df.applymap(lambda x: x['value'])

# Concatenate
county_df = pd.concat([county_df, div_df])
county_df.drop_duplicates(inplace=True)

# Unpack state, country etc. that each county is located in
county_df[['state', 'country', 'continent', 'planet', 'other']] = county_df['parents'].str.split(', ', expand=True)

# Filter
county_df = county_df[(county_df['country'] == 'United States') & (county_df['state'].isin(occ['stateProvince'].unique()))].copy()
county_df.head()
# Out:
#                                   place      type     name  \
# 17   http://vocab.getty.edu/tgn/2002238  counties    Adams
# 41   http://vocab.getty.edu/tgn/1002138  counties  Alameda
# 89   http://vocab.getty.edu/tgn/1002145  counties   Alpine
# 95   http://vocab.getty.edu/tgn/2002239  counties   Asotin
# 101  http://vocab.getty.edu/tgn/1002146  counties   Amador
#
#                                                parents       state  \
# 17   Washington, United States, North and Central A...  Washington
# 41   California, United States, North and Central A...  California
# 89   California, United States, North and Central A...  California
# 95   Washington, United States, North and Central A...  Washington
# 101  California, United States, North and Central A...  California
#
#            country                  continent planet other
# 17   United States  North and Central America  World  None
# 41   United States  North and Central America  World  None
# 89   United States  North and Central America  World  None
# 95   United States  North and Central America  World  None
# 101  United States  North and Central America  World  None

# %%
## Check MARINe counties

for c in occ['county'].unique():
    if c not in county_df['name'].unique():
        print('County {} is not listed in GTGN. Double check name'.format(c))

# %% [markdown]
# All county names appear to be accurate.

# %%
## Clean countryCode

occ['countryCode'] = occ['countryCode'].str.replace('United States', 'US')
occ.head()
# Out:
#                       eventID              eventDate  \
# 0  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 1  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 2  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 3  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 4  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
#
#                                            datasetID      locality  county  \
# 0  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 1  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 2  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 3  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 4  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
#
#   stateProvince countryCode  decimalLatitude  decimalLongitude
# 0    California          US        33.570782        -117.83773
# 1    California          US        33.570782        -117.83773
# 2    California          US        33.570782        -117.83773
# 3    California          US        33.570782        -117.83773
# 4    California          US        33.570782        -117.83773

# %%
## coordinatUncertaintyInMeters

occ['coordinateUncertaintyInMeters'] = 350
occ.head()
# Out:
#                       eventID              eventDate  \
# 0  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 1  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 2  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 3  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 4  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
#
#                                            datasetID      locality  county  \
# 0  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 1  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 2  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 3  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 4  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
#
#   stateProvince countryCode  decimalLatitude  decimalLongitude  \
# 0    California          US        33.570782        -117.83773
# 1    California          US        33.570782        -117.83773
# 2    California          US        33.570782        -117.83773
# 3    California          US        33.570782        -117.83773
# 4    California          US        33.570782        -117.83773
#
#    coordinateUncertaintyInMeters
# 0                            350
# 1                            350
# 2                            350
# 3                            350
# 4                            350

# %%
## Add minimumDepthInMeters, maximumDepthInMeters, samplingProtocol and samplingEffort

# Depth
occ['minimumDepthInMeters'] = 0
occ['maximumDepthInMeters'] = 0

# samplingProtocol
occ['samplingProtocol'] = 'phototransect'

# samplingEffort
occ['samplingEffort'] = data['num_plots_sampled']
occ.head()
# Out:
#                       eventID              eventDate  \
# 0  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 1  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 2  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 3  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 4  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
#
#                                            datasetID      locality  county  \
# 0  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 1  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 2  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 3  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 4  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
#
#   stateProvince countryCode  decimalLatitude  decimalLongitude  \
# 0    California          US        33.570782        -117.83773
# 1    California          US        33.570782        -117.83773
# 2    California          US        33.570782        -117.83773
# 3    California          US        33.570782        -117.83773
# 4    California          US        33.570782        -117.83773
#
#    coordinateUncertaintyInMeters  minimumDepthInMeters  maximumDepthInMeters  \
# 0                            350                     0                     0
# 1                            350                     0                     0
# 2                            350                     0                     0
# 3                            350                     0                     0
# 4                            350                     0                     0
#
#   samplingProtocol  samplingEffort
# 0    phototransect               5
# 1    phototransect               5
# 2    phototransect               5
# 3    phototransect               5
# 4    phototransect               5

# %% [markdown]
# **Do we want to distinguish between photoplots and phototransects here in the samplingProtocol column? If so, do we want to update samplingEffort to say "3 plot(s)" or "3 transect(s)" as is appropriate?**

# %%
## occurrenceID

occ['occurrenceID'] = data.groupby(['site_code', 'min_survey_date', 'max_survey_date'])['lumping_code'].cumcount()+1
occ['occurrenceID'] = occ['eventID'] + '_' + occ['occurrenceID'].astype(str)
occ.head()
# Out:
#                       eventID              eventDate  \
# 0  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 1  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 2  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 3  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 4  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
#
#                                            datasetID      locality  county  \
# 0  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 1  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 2  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 3  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 4  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
#
#   stateProvince countryCode  decimalLatitude  decimalLongitude  \
# 0    California          US        33.570782        -117.83773
# 1    California          US        33.570782        -117.83773
# 2    California          US        33.570782        -117.83773
# 3    California          US        33.570782        -117.83773
# 4    California          US        33.570782        -117.83773
#
#    coordinateUncertaintyInMeters  minimumDepthInMeters  maximumDepthInMeters  \
# 0                            350                     0                     0
# 1                            350                     0                     0
# 2                            350                     0                     0
# 3                            350                     0                     0
# 4                            350                     0                     0
#
#   samplingProtocol  samplingEffort                  occurrenceID
# 0    phototransect               5  CRCO_2002-12-06_2002-12-06_1
# 1    phototransect               5  CRCO_2002-12-06_2002-12-06_2
# 2    phototransect               5  CRCO_2002-12-06_2002-12-06_3
# 3    phototransect               5  CRCO_2002-12-06_2002-12-06_4
# 4    phototransect               5  CRCO_2002-12-06_2002-12-06_5

# %%
## scientificName

# Get species codes
occ['scientificName'] = data['lumping_code']

# Create scientificName column in species table
sp = species[['lumping_code', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']]
sp = sp.replace('NULL', np.nan, regex=True)
sp['scientificName'] = sp['species'].combine_first(sp['genus'])
sp['scientificName'] = sp['scientificName'].combine_first(sp['family'])
sp['scientificName'] = sp['scientificName'].combine_first(sp['order'])
sp['scientificName'] = sp['scientificName'].combine_first(sp['class'])
sp['scientificName'] = sp['scientificName'].combine_first(sp['phylum'])
sp['scientificName'] = sp['scientificName'].combine_first(sp['kingdom'])

# Build dictionary mapping codes to names
sp_dict = dict(zip(sp['lumping_code'], sp['scientificName']))

# Match OTHALG with Biota
sp_dict['OTHALG'] = 'Biota'

# Replace codes with names in occ
occ['scientificName'] = occ['scientificName'].replace(sp_dict)
occ.head()
# Out:
#                       eventID              eventDate  \
# 0  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 1  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 2  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 3  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
# 4  CRCO_2002-12-06_2002-12-06  2002-12-06/2002-12-06
#
#                                            datasetID      locality  county  \
# 0  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 1  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 2  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 3  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
# 4  MARINe LTM - percent cover from photoplots and...  Crystal Cove  Orange
#
#   stateProvince countryCode  decimalLatitude  decimalLongitude  \
# 0    California          US        33.570782        -117.83773
# 1    California          US        33.570782        -117.83773
# 2    California          US        33.570782        -117.83773
# 3    California          US        33.570782        -117.83773
# 4    California          US        33.570782        -117.83773
#
#    coordinateUncertaintyInMeters  minimumDepthInMeters  maximumDepthInMeters  \
# 0                            350                     0                     0
# 1                            350                     0                     0
# 2                            350                     0                     0
# 3                            350                     0                     0
# 4                            350                     0                     0
#
#   samplingProtocol  samplingEffort                  occurrenceID  \
# 0    phototransect               5  CRCO_2002-12-06_2002-12-06_1
# 1    phototransect               5  CRCO_2002-12-06_2002-12-06_2
# 2    phototransect               5  CRCO_2002-12-06_2002-12-06_3
# 3    phototransect               5  CRCO_2002-12-06_2002-12-06_4
# 4    phototransect               5  CRCO_2002-12-06_2002-12-06_5
#
#                  scientificName
# 0                  Anthopleura
# 1                Corallinaceae
# 2               Polyplacophora
# 3  Chondracanthus canaliculatus
# 4                     Sessilia

# %%
## Get unique names

names = occ['scientificName'].unique()
names
# Out:
# array(['Anthopleura ', 'Corallinaceae ', 'Polyplacophora ',
#        'Chondracanthus canaliculatus', 'Sessilia ',
#        'Cladophora columbiana', 'Egregia menziesii', 'Eisenia arborea',
#        'Endocladia muricata', 'Phaeophyceae ', 'Fucus distichus',
#        'Stephanocystis ', 'Hesperophycus californicus', 'Gastropoda ',
#        'Lottia gigantea', 'Mastocarpus ', 'Mazzaella affinis',
#        'Mazzaella ', 'Mytilus californianus', 'Plantae ', 'Biota',
#        'Thecostraca ', 'Chromista ', '(Division) Chlorophyta',
#        'Animalia ', '(Division) Rhodophyta', 'Pelvetiopsis limitata',
#        'Sabellariidae ', 'Phyllospadix ', 'Pisaster ochraceus',
#        'Pollicipes polymerus', 'Pyropia ', nan, 'Sargassum muticum',
#        'Mytilidae ', 'Silvetia compressa', 'Tetraclita squamosa',
#        'Ulvophyceae ', 'Neorhodomela larix', 'Semibalanus cariosus',
#        'Mytilus ', 'Hedophyllum sessile', 'Zostera marina'], dtype=object)

# %% [markdown]
# **Note** that there are still NaN values in scientificName. Where are they coming from?
#
# The following codes are still matched to NaN:
# - OTHALG
# - OTHSUB
# - ROCK
# - SAND
# - TAR
#
# Rock, sand and tar are obviously abiotic and can't be matched to a species name. **Did Abby say these could remain in the dataset, they just wouldn't show up in OBIS?** OTHALG is pretty clearly other algae. OTHSUB must be other substrate - also abiotic.
#
# **OTHALG probably should be matched to Biota. I've changed this above.**
