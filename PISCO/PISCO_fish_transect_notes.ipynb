# %% [markdown]
# # PISCO - fish transect data - dealing with the notes column
#
# I would like to make some effort to extract useful information and tidy the notes column. **A few of the notes are pretty inappropriate and/or use names. However, since PISCO has already shared them publicly, I assume it continues to be OK to do so.** Many, many of the notes contain potentially useful information.
#
# A large number of the notes contain sex information. I can probably extract this. I need to look for and pull:
# - M
# - F
# - M;
# - F;
# - MALE
# - FEMALE
# - FEAMLE
# - MALE;
# - FEMALE;
# - TRANSITIONAL;
# - TRANSITION
# - MALE,
#
# There is also some life stage information:
# - JUVENILE
# - JUVENILE;
# - JEVENILE
#
# Sometimes, sex is uncertain (e.g. 'M?'). I'll leave these in the notes.
#
# Note cleaning:
# - Explore cleaning lowercase versus capitals
# - Some notes are preceeded by '. '

# %%
## Imports

import pandas as pd
import numpy as np
from random import randint, seed, sample

# %%
## Load data

fish_occ = pd.read_csv('fish_occ.csv', dtype={'sex':str, 'lifeStage':str})
fish = pd.read_csv('fish.csv', dtype={'transect':str, 'sex':str, 'site_name_old':str})

print(fish_occ.shape)
fish.shape
# Out:
# (369262, 14)
# (381693, 29)

# %% [markdown]
# **Note** that the above number of records are different because fish still includes records where classcode = NO_ORG and a single record where count = NaN.

# %%
## Drop record where count is missing

print(fish.shape)
fish.dropna(subset=['count'], inplace=True)
fish = fish[fish['classcode'] != 'NO_ORG']
fish.reset_index(drop=True, inplace=True)
fish.shape
# Out:
# (381693, 29)
# (369262, 29)

# %%
## Obtain relevant records from fish_occ (going to try doing everything in fish_occ)

notes = fish[['site', 'survey_date', 'classcode', 'count', 'sex', 'notes']].copy()
notes.shape
# Out:
# (369262, 6)

# %%
## Grab a random subset of records to make troubleshooting easier

seed(42)
idx = sample(range(notes.shape[0]), 1000)
subset = notes.iloc[idx, :].copy()

# %%
## Extract sex information from notes

sex_notes = []
sex_options = ['M', 'F', 'MALE', 'FEMALE', 'FEAMLE', 'MALES', 'FEMALES', 'TRANSITIONAL', 'TRANSITION', 'TRANNY']

for note in subset['notes']:
    
    colon_overlap = []
    comma_overlap = []
    slash_overlap = []
    
    if note == note:
        
        colon_split = list(map(str.strip, note.split(';')))
        if (len(colon_split) > 1) & ('' not in colon_split):
            colon_overlap = list(set(sex_options) & set(colon_split))
            
        comma_split = list(map(str.strip, note.split(',')))
        if (len(comma_split) > 1) & ('' not in comma_split):
            comma_overlap = list(set(sex_options) & set(comma_split))
            
        slash_split = list(map(str.strip, note.split('/')))
        if (len(slash_split) > 1) & ('' not in slash_split):
            slash_overlap = list(set(sex_options) & set(slash_split))
          
        
        if note in sex_options:
            sex_notes.append(note)
        elif colon_overlap != []:
            sex_notes.extend(colon_overlap)
        elif comma_overlap != []:
            sex_notes.extend(comma_overlap)
        elif (slash_overlap != []) & (len(slash_overlap) == 1):
            sex_notes.extend(slash_overlap)
        
        else:
            sex_notes.append(np.nan)
            
    else:
        sex_notes.append(np.nan)

# %%
## Inspect outcome

subset['sex_notes'] = sex_notes

pd.set_option('display.max_rows', 60)
subset[(subset['sex'].isna() == False) | (subset['notes'].isna() == False)]
# Out:
#                             site  survey_date classcode  count       sex  \
# 340726           PYRAMID_POINT_3     20180728      HDEC    1.0    FEMALE
# 221571       ANACAPA_WEST_ISLE_E     20090928      SPUL    1.0  JUVENILE
# 178389                NAPLES_CEN     20060913      HCAR    1.0       NaN
# 176472         SCI_COCHE_POINT_E     20060906      RTOX    1.0       NaN
# 199191     SCI_SAN_PEDRO_POINT_E     20080801      SPUL    1.0    FEMALE
# ...                          ...          ...       ...    ...       ...
# 319622  SRI_JOHNSONS_LEE_SOUTH_E     20170925      SPUL    1.0    FEMALE
# 327710  SRI_JOHNSONS_LEE_SOUTH_E     20180822      SPUL    1.0    FEMALE
# 309219              SCI_FORNEY_W     20161214      SPUL    1.0    FEMALE
# 117864            SAUNDERS_MPA_1     20160912      HDEC    1.0       NaN
# 339547          POINT_CABRILLO_3     20170730      SNEB    1.0       NaN
#
#                                                     notes sex_notes
# 340726                                                NaN       NaN
# 221571                                           JUVENILE       NaN
# 178389  HIGH RELIEF BEDROCK (NAPLES PROPER/ 3 FINGERS)...       NaN
# 176472  MED/HIGH RELIEF BEDROCK, BOULDERS W/ SAND ON O...       NaN
# 199191                                             FEMALE    FEMALE
# ...                                                   ...       ...
# 319622                                             FEMALE    FEMALE
# 327710                                             FEMALE    FEMALE
# 309219                                             FEMALE    FEMALE
# 117864                                             NO SEX       NaN
# 339547                                          . ON WALL       NaN
#
# [162 rows x 7 columns]

# %%
## Clean sex_notes

print(subset['sex_notes'].unique())
subset['sex_notes'].replace({'F':'female',
                  'M':'male',
                  'FEMALE':'female',
                  'MALE':'male',
                  'MALES':'male',
                  'FEMALES':'female',
                  'FEAMLE':'female',
                  'TRANSITIONAL':'transitional',
                  'TRANNY':'transitional',
                  'TRANSITION':'transitional'}, inplace=True)
print(subset['sex_notes'].unique())

pd.set_option('display.max_rows', 60)
subset[(subset['sex'].isna() == False) | (subset['notes'].isna() == False)]
# Out:
# [nan 'FEMALE' 'MALE' 'F' 'M']
# [nan 'female' 'male']
#                             site  survey_date classcode  count       sex  \
# 340726           PYRAMID_POINT_3     20180728      HDEC    1.0    FEMALE
# 221571       ANACAPA_WEST_ISLE_E     20090928      SPUL    1.0  JUVENILE
# 178389                NAPLES_CEN     20060913      HCAR    1.0       NaN
# 176472         SCI_COCHE_POINT_E     20060906      RTOX    1.0       NaN
# 199191     SCI_SAN_PEDRO_POINT_E     20080801      SPUL    1.0    FEMALE
# ...                          ...          ...       ...    ...       ...
# 319622  SRI_JOHNSONS_LEE_SOUTH_E     20170925      SPUL    1.0    FEMALE
# 327710  SRI_JOHNSONS_LEE_SOUTH_E     20180822      SPUL    1.0    FEMALE
# 309219              SCI_FORNEY_W     20161214      SPUL    1.0    FEMALE
# 117864            SAUNDERS_MPA_1     20160912      HDEC    1.0       NaN
# 339547          POINT_CABRILLO_3     20170730      SNEB    1.0       NaN
#
#                                                     notes sex_notes
# 340726                                                NaN       NaN
# 221571                                           JUVENILE       NaN
# 178389  HIGH RELIEF BEDROCK (NAPLES PROPER/ 3 FINGERS)...       NaN
# 176472  MED/HIGH RELIEF BEDROCK, BOULDERS W/ SAND ON O...       NaN
# 199191                                             FEMALE    female
# ...                                                   ...       ...
# 319622                                             FEMALE    female
# 327710                                             FEMALE    female
# 309219                                             FEMALE    female
# 117864                                             NO SEX       NaN
# 339547                                          . ON WALL       NaN
#
# [162 rows x 7 columns]

# %%
## Add in cleaned sex column from fish_occ

# Get occ_subset
occ_subset = fish_occ.iloc[idx, :].copy()

# Add
subset['occ_sex'] = occ_subset['sex']

# Check
pd.set_option('display.max_rows', 60)
subset[(subset['sex'].isna() == False) | (subset['notes'].isna() == False)]
# Out:
#                             site  survey_date classcode  count       sex  \
# 340726           PYRAMID_POINT_3     20180728      HDEC    1.0    FEMALE
# 221571       ANACAPA_WEST_ISLE_E     20090928      SPUL    1.0  JUVENILE
# 178389                NAPLES_CEN     20060913      HCAR    1.0       NaN
# 176472         SCI_COCHE_POINT_E     20060906      RTOX    1.0       NaN
# 199191     SCI_SAN_PEDRO_POINT_E     20080801      SPUL    1.0    FEMALE
# ...                          ...          ...       ...    ...       ...
# 319622  SRI_JOHNSONS_LEE_SOUTH_E     20170925      SPUL    1.0    FEMALE
# 327710  SRI_JOHNSONS_LEE_SOUTH_E     20180822      SPUL    1.0    FEMALE
# 309219              SCI_FORNEY_W     20161214      SPUL    1.0    FEMALE
# 117864            SAUNDERS_MPA_1     20160912      HDEC    1.0       NaN
# 339547          POINT_CABRILLO_3     20170730      SNEB    1.0       NaN
#
#                                                     notes sex_notes occ_sex
# 340726                                                NaN       NaN  female
# 221571                                           JUVENILE       NaN     NaN
# 178389  HIGH RELIEF BEDROCK (NAPLES PROPER/ 3 FINGERS)...       NaN     NaN
# 176472  MED/HIGH RELIEF BEDROCK, BOULDERS W/ SAND ON O...       NaN     NaN
# 199191                                             FEMALE    female  female
# ...                                                   ...       ...     ...
# 319622                                             FEMALE    female  female
# 327710                                             FEMALE    female  female
# 309219                                             FEMALE    female  female
# 117864                                             NO SEX       NaN     NaN
# 339547                                          . ON WALL       NaN     NaN
#
# [162 rows x 8 columns]

# %%
## Create new column merging information from occ_sex and sex_notes

new_sex = [subset['occ_sex'].iloc[i] if subset['occ_sex'].iloc[i] == subset['occ_sex'].iloc[i] else subset['sex_notes'].iloc[i] for i in range(subset.shape[0])]
subset['new_sex'] = new_sex

# Check
pd.set_option('display.max_rows', 60)
subset[(subset['occ_sex'].isna() == False) & (subset['sex_notes'].isna() == False) & (subset['occ_sex'] != subset['sex_notes'])]
# Out:
# Empty DataFrame
# Columns: [site, survey_date, classcode, count, sex, notes, sex_notes, occ_sex, new_sex]
# Index: []

# %%
## Replace sex column in occ_subset with new_sex

occ_subset['sex'] = subset['new_sex']
occ_subset.head()
# Out:
#                                            eventID  \
# 335243  SBI-Southeast_Sealion_20041009_INNER_BOT_1
# 58369               PARANOIDS_20080925_INMID_BOT_2
# 13112              HOPKINS_DC_20020828_INNER_BOT_1
# 144194          SCI_FORNEY_E_20030911_OUTMID_BOT_2
# 128393             HOPKINS_UC_20180720_OUTER_BOT_3
#
#                                            occurrenceID  \
# 335243  SBI-Southeast_Sealion_20041009_INNER_BOT_1_occ7
# 58369               PARANOIDS_20080925_INMID_BOT_2_occ2
# 13112              HOPKINS_DC_20020828_INNER_BOT_1_occ1
# 144194          SCI_FORNEY_E_20030911_OUTMID_BOT_2_occ3
# 128393             HOPKINS_UC_20180720_OUTER_BOT_3_occ5
#
#                 vernacularName          scientificName  \
# 335243  Kelp Bass, Calico Bass   Paralabrax clathratus
# 58369        Painted Greenling        Oxylebius pictus
# 13112          Black Surfperch      Embiotoca jacksoni
# 144194         Black Surfperch      Embiotoca jacksoni
# 128393           Blackeye Goby  Rhinogobiops nicholsii
#
#                                  scientificNameID  taxonID nameAccordingTo  \
# 335243  urn:lsid:marinespecies.org:taxname:282054   282054           WoRMS
# 58369   urn:lsid:marinespecies.org:taxname:240743   240743           WoRMS
# 13112   urn:lsid:marinespecies.org:taxname:240746   240746           WoRMS
# 144194  urn:lsid:marinespecies.org:taxname:240746   240746           WoRMS
# 128393  urn:lsid:marinespecies.org:taxname:282580   282580           WoRMS
#
#        occurrenceStatus     basisOfRecord identificationQualifier  sex  \
# 335243          present  HumanObservation                     NaN  NaN
# 58369           present  HumanObservation                     NaN  NaN
# 13112           present  HumanObservation                     NaN  NaN
# 144194          present  HumanObservation                     NaN  NaN
# 128393          present  HumanObservation                     NaN  NaN
#
#        lifeStage  organismQuantity              organismQuantityType
# 335243       NaN               1.0  number of individuals per 120 m3
# 58369        NaN               1.0  number of individuals per 120 m3
# 13112        NaN               1.0  number of individuals per 120 m3
# 144194       NaN               8.0  number of individuals per 120 m3
# 128393       NaN               1.0  number of individuals per 120 m3

# %%
## Check

subset[subset['occ_sex'] == 'female'].shape[0] # 49
subset[subset['new_sex'] == 'female'].shape[0] # 57
occ_subset[occ_subset['sex'] == 'female'].shape[0]
# Out:
# 57

# %% [markdown]
# Ok, that seems to have worked. Let's see if we can try on the whole dataset now.

# %%
## Extract sex information from notes

sex_notes = []
sex_options = ['M', 'F', 'MALE', 'FEMALE', 'FEAMLE', 'MALES', 'FEMALES', 'TRANSITIONAL', 'TRANSITION', 'TRANNY']

for note in notes['notes']:
    
    colon_overlap = []
    comma_overlap = []
    slash_overlap = []
    
    if note == note:
        
        colon_split = list(map(str.strip, note.split(';')))
        if (len(colon_split) > 1) & ('' not in colon_split):
            colon_overlap = list(set(sex_options) & set(colon_split))
            
        comma_split = list(map(str.strip, note.split(',')))
        if (len(comma_split) > 1) & ('' not in comma_split):
            comma_overlap = list(set(sex_options) & set(comma_split))
            
        slash_split = list(map(str.strip, note.split('/')))
        if (len(slash_split) > 1) & ('' not in slash_split):
            slash_overlap = list(set(sex_options) & set(slash_split))
          
        
        if note in sex_options:
            sex_notes.append(note)
        elif colon_overlap != []:
            sex_notes.extend(colon_overlap)
        elif comma_overlap != []:
            sex_notes.extend(comma_overlap)
        elif (slash_overlap != []) & (len(slash_overlap) == 1):
            sex_notes.extend(slash_overlap)
        
        else:
            sex_notes.append(np.nan)
            
    else:
        sex_notes.append(np.nan)

# %%
## Inspect outcome

notes['sex_notes'] = sex_notes

pd.set_option('display.max_rows', 60)
notes[(notes['sex'].isna() == False) | (notes['notes'].isna() == False)].iloc[10000:10010, :]
# Out:
#                      site  survey_date classcode  count     sex  \
# 168024  SCI_YELLOWBANKS_W     20051006      EJAC    1.0     NaN
# 168025  SCI_YELLOWBANKS_W     20051006      HRUB    1.0     NaN
# 168026  SCI_YELLOWBANKS_W     20051006      HSEM    1.0    MALE
# 168027  SCI_YELLOWBANKS_W     20051006      PCLA    3.0     NaN
# 168028  SCI_YELLOWBANKS_W     20051006      PCLA    2.0     NaN
# 168029  SCI_YELLOWBANKS_W     20051006      PCLA    2.0     NaN
# 168030  SCI_YELLOWBANKS_W     20051006      PCLA    2.0     NaN
# 168031  SCI_YELLOWBANKS_W     20051006      SATR    1.0     NaN
# 168032  SCI_YELLOWBANKS_W     20051006      SPUL    1.0  FEMALE
# 168033  SCI_YELLOWBANKS_W     20051006      BFRE    1.0     NaN
#
#                          notes sex_notes
# 168024          NO CANOPY KELP       NaN
# 168025          NO CANOPY KELP       NaN
# 168026    MALE; NO CANOPY KELP      MALE
# 168027          NO CANOPY KELP       NaN
# 168028          NO CANOPY KELP       NaN
# 168029          NO CANOPY KELP       NaN
# 168030          NO CANOPY KELP       NaN
# 168031          NO CANOPY KELP       NaN
# 168032  FEMALE; NO CANOPY KELP    FEMALE
# 168033          NO CANOPY KELP       NaN

# %%
## Clean sex_notes

print(notes['sex_notes'].unique())
notes['sex_notes'].replace({'F':'female',
                  'M':'male',
                  'FEMALE':'female',
                  'MALE':'male',
                  'MALES':'male',
                  'FEMALES':'female',
                  'FEAMLE':'female',
                  'TRANSITIONAL':'transitional',
                  'TRANNY':'transitional',
                  'TRANSITION':'transitional'}, inplace=True)
print(notes['sex_notes'].unique())

notes.head()
# Out:
# [nan 'F' 'M' 'FEMALE' 'MALE' 'TRANSITIONAL' 'MALES' 'FEMALES' 'TRANNY'
#  'TRANSITION' 'FEAMLE']
# [nan 'female' 'male' 'transitional']
#          site  survey_date classcode  count  sex notes sex_notes
# 0  HOPKINS_DC     19990907      ELAT    1.0  NaN   NaN       NaN
# 1  HOPKINS_DC     19990907      ELAT    1.0  NaN   NaN       NaN
# 2  HOPKINS_DC     19990907      HDEC    1.0  NaN   NaN       NaN
# 3  HOPKINS_DC     19990907      OCAL   85.0  NaN   NaN       NaN
# 4  HOPKINS_DC     19990907       OYT  100.0  NaN   NaN       NaN

# %%
## Add in cleaned sex column from fish_occ

# Add
notes['occ_sex'] = fish_occ['sex']

# Check
pd.set_option('display.max_rows', 60)
notes[(notes['sex'].isna() == False) | (notes['notes'].isna() == False)].iloc[5000:5100, :]
# Out:
#                        site  survey_date classcode  count  sex         notes  \
# 115567           HOPKINS_UC     20160818      HDEC    1.0  NaN        FEMALE
# 115635           HOPKINS_UC     20160818      HDEC    1.0  NaN  NO SEX GIVEN
# 115645           HOPKINS_UC     20160818      HDEC    1.0  NaN  NO SEX GIVEN
# 115646           HOPKINS_UC     20160818      HDEC    1.0  NaN  NO SEX GIVEN
# 115904         MONASTERY_DC     20160824      HDEC    1.0  NaN          MALE
# ...                     ...          ...       ...    ...  ...           ...
# 119901  DEL_MAR_REFERENCE_2     20170802      HDEC    1.0  NaN          MALE
# 119921  DEL_MAR_REFERENCE_2     20170802      HDEC    1.0  NaN          MALE
# 119928  DEL_MAR_REFERENCE_2     20170802      HDEC    1.0  NaN          MALE
# 119929  DEL_MAR_REFERENCE_2     20170802      HDEC    1.0  NaN        FEMALE
# 119934  DEL_MAR_REFERENCE_2     20170802      HDEC    1.0  NaN          MALE
#
#        sex_notes occ_sex
# 115567    female     NaN
# 115635       NaN     NaN
# 115645       NaN     NaN
# 115646       NaN     NaN
# 115904      male     NaN
# ...          ...     ...
# 119901      male     NaN
# 119921      male     NaN
# 119928      male     NaN
# 119929    female     NaN
# 119934      male     NaN
#
# [100 rows x 8 columns]

# %%
## Create new column merging information from occ_sex and sex_notes

new_sex = [notes['occ_sex'].iloc[i] if notes['occ_sex'].iloc[i] == notes['occ_sex'].iloc[i] else notes['sex_notes'].iloc[i] for i in range(notes.shape[0])]
notes['new_sex'] = new_sex

# %%
# Check
pd.set_option('display.max_rows', 600)
# notes[(notes['occ_sex'].isna() == False) & (notes['sex_notes'].isna() == False) & (notes['occ_sex'] != notes['sex_notes'])]
notes[(notes['occ_sex'].isna() == False) & (notes['sex_notes'].isna() == False) & (notes['occ_sex'] != notes['sex_notes'])]
# Out:
# Empty DataFrame
# Columns: [site, survey_date, classcode, count, sex, notes, sex_notes, occ_sex, new_sex]
# Index: []

# %%
## Replace sex column in fish_occ with new_sex

fish_occ['sex'] = notes['new_sex']
fish_occ.head()
# Out:
#                            eventID                          occurrenceID  \
# 0  HOPKINS_DC_19990907_INNER_BOT_1  HOPKINS_DC_19990907_INNER_BOT_1_occ1
# 1  HOPKINS_DC_19990907_INNER_BOT_1  HOPKINS_DC_19990907_INNER_BOT_1_occ2
# 2  HOPKINS_DC_19990907_INNER_BOT_1  HOPKINS_DC_19990907_INNER_BOT_1_occ3
# 3  HOPKINS_DC_19990907_INNER_BOT_1  HOPKINS_DC_19990907_INNER_BOT_1_occ4
# 4  HOPKINS_DC_19990907_INNER_BOT_1  HOPKINS_DC_19990907_INNER_BOT_1_occ5
#
#                  vernacularName           scientificName  \
# 0             Striped Surfperch      Embiotoca lateralis
# 1             Striped Surfperch      Embiotoca lateralis
# 2                Kelp Greenling  Hexagrammos decagrammus
# 3                      Senorita     Oxyjulis californica
# 4  Olive Or Yellowtail Rockfish                 Sebastes
#
#                             scientificNameID  taxonID nameAccordingTo  \
# 0  urn:lsid:marinespecies.org:taxname:240740   240740           WoRMS
# 1  urn:lsid:marinespecies.org:taxname:240740   240740           WoRMS
# 2  urn:lsid:marinespecies.org:taxname:240732   240732           WoRMS
# 3  urn:lsid:marinespecies.org:taxname:240727   240727           WoRMS
# 4  urn:lsid:marinespecies.org:taxname:126175   126175           WoRMS
#
#   occurrenceStatus     basisOfRecord  \
# 0          present  HumanObservation
# 1          present  HumanObservation
# 2          present  HumanObservation
# 3          present  HumanObservation
# 4          present  HumanObservation
#
#                      identificationQualifier  sex lifeStage  organismQuantity  \
# 0                                        NaN  NaN       NaN               1.0
# 1                                        NaN  NaN       NaN               1.0
# 2                                        NaN  NaN       NaN               1.0
# 3                                        NaN  NaN       NaN              85.0
# 4  Sebastes serranoides or Sebastes flavidus  NaN       NaN             100.0
#
#                organismQuantityType
# 0  number of individuals per 120 m3
# 1  number of individuals per 120 m3
# 2  number of individuals per 120 m3
# 3  number of individuals per 120 m3
# 4  number of individuals per 120 m3

# %%
## Check

notes[notes['occ_sex'] == 'female'].shape[0] # 16528
notes[notes['new_sex'] == 'female'].shape[0] # 18031
fish_occ[fish_occ['sex'] == 'female'].shape[0]
# Out:
# 18031

# %%
## Save for visual inspection

fish_occ.to_csv('occ.csv', index=False, na_rep='NaN')
