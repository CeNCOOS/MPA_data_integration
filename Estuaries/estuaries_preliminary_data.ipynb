# %% [markdown]
# # Estuaries - preliminary data
#
# Received from Christine Whitcraft on July 3, 2021. These seem to be raw data, and the data/format is not fully finalized. They can serve as examples for what kind of data we might expect.
#
# ## Vegetation Surveys
#
# Five estuaries (Goleta Slough, Ventura River, Malibu Lagoon, Newport Bay and Batiquitos Lagoon) were surveyed in March/April. I think the vision is to sample twice yearly in the spring and fall.
#
# There are 3 stations per estuary - one on each "arm" (I think).
#
# Two or 3 replicate transects are completed per station, ideally in low, mid, and upland habitats.
#
# Along each transect, percent cover is estimated in 5 replicate plots. Percent cover of the following cover types is currently being measured:
# - open
# - dead plant material
# - vegetative
# - trash
# - woody debris
# - litter
# - wrack
# - macroalgae
# - water
#
# Scientific names are provided if relevant. The height of the tallest plant is often included, when relevant.
#
# Numbers of invertebrates/invertebrate burrows are also counted within each replicate plot. These counts are provided as densities.
#
# ## Fish Seines and Cast Nets
#
# Five estuaries (Goleta Slough, Ventura River, Malibu Lagoon, Newport Bay and Batiquitos Lagoon) were surveyed in March/April. I think the vision is to sample twice yearly in the spring and fall.
#
# There are 3 stations per estuary - one on each "arm" (I think).
#
# Fish seines and cast nets are conducted at each station. There are between 3 and 9 net replicates for each seine survey (mode=3), and between 6 and 25 cast nets for each survey (mode=6). Batiquitos Lagoon tends to have many more replicates than other estuaries; not sure why.
#
# Regardless of survey type, each fish caught is identified and counted. The total number of individuals caught per species (identified by common name) is presented in the abundance data.
#
# Each fish caught is also measured (total length?). If a lot of fish of a particular species is caught, only a subset is measured.

# %%
## Imports

import pandas as pd
import numpy as np
import xlrd

# %%
## Load data

## Vegetation Surveys ------
# Load excel file
veg = pd.ExcelFile('SOP_11_Vegetation_data_withsummary.xls')
print(veg.sheet_names)

# Extract relevant sheets into dataframes
veg_sample = pd.read_excel(veg, 'sample_metadata')
veg_cover = pd.read_excel(veg, 'vegetativecover_data')
veg_epi = pd.read_excel(veg, 'epifauna_data')

## Fish Seines ------
# Load excel file
fish = pd.ExcelFile('SOP_9_Fish_Seines_data.xls')
print(fish.sheet_names)

# Extract relevant sheets into dataframes
fish_sample = pd.read_excel(fish, 'sample_metadata')
fish_abundance = pd.read_excel(fish, 'abundance_data')
fish_length = pd.read_excel(fish, 'length_data')
# Out:
# ['protocol_metadata', 'sample_metadata', 'Veg summary stats', 'vegetativecover_data', 'epifauna_data', 'glossary', 'Lookup Lists']
# ['protocol_metadata', 'sample_metadata', 'abundance_data', 'length_data', 'glossary', 'Lookup Lists']

# %% [markdown]
# ## Vegetation Surveys
#
# Right now, the sample metadata doesn't add much. Just whether the tide was going in or out and who collected/entered the data. Lat, lons are not entered.

# %%
## Look at sample metadata

veg_sample.head()
# Out:
#    SiteID    EstuaryName  StationNo SampleCollectionDate  Weather      Tide  \
# 0  SC-GOL  Goleta Slough          1           2021-03-25      NaN  outgoing
# 1  SC-GOL  Goleta Slough          1           2021-03-25      NaN  outgoing
# 2  SC-GOL  Goleta Slough          1           2021-03-25      NaN  outgoing
# 3  SC-GOL  Goleta Slough          2           2021-03-23      NaN  outgoing
# 4  SC-GOL  Goleta Slough          2           2021-03-23      NaN  outgoing
#
#    TransectReplicate TransectBeginLatitude  TransectBeginLongitude  \
# 0                  1                   NaN                     NaN
# 1                  2                   NaN                     NaN
# 2                  3       did not collect                     NaN
# 3                  1                   NaN                     NaN
# 4                  2                   NaN                     NaN
#
#    TransectEndLatitude  TransectEndLongitude Habitat         DataCollector  \
# 0                  NaN                   NaN     low  Christine, Sebastian
# 1                  NaN                   NaN     mid  Christine, Sebastian
# 2                  NaN                   NaN  upland  Christine, Sebastian
# 3                  NaN                   NaN     low     Parker, Sebastian
# 4                  NaN                   NaN     mid     Parker, Sebastian
#
#   DataEntryPerson  SampleMetadataNotes
# 0      Jan Walker                  NaN
# 1      Jan Walker                  NaN
# 2      Jan Walker                  NaN
# 3      Jan Walker                  NaN
# 4      Jan Walker                  NaN

# %% [markdown]
# The percent cover data gives the estimated cover of a number of cover types (including plants and macroalgae) in 5 replicate plots along each transect.

# %%
## Look at percent cover data

veg_cover.head()
# Out:
#    SiteID    EstuaryName  StationNo SampleCollectionDate  TransectReplicate  \
# 0  SC-GOL  Goleta Slough          1           2021-03-25                  1
# 1  SC-GOL  Goleta Slough          1           2021-03-25                  1
# 2  SC-GOL  Goleta Slough          1           2021-03-25                  1
# 3  SC-GOL  Goleta Slough          1           2021-03-25                  1
# 4  SC-GOL  Goleta Slough          1           2021-03-25                  1
#
#   Habitat classification PlotReplicate Substrate            CoverType  \
# 0              mid marsh             1       NaN                 open
# 1              mid marsh             1       NaN  dead plant material
# 2              mid marsh             1       NaN           vegetative
# 3              mid marsh             1       NaN           vegetative
# 4              mid marsh             1       NaN           vegetative
#
#   Live/Dead      ScientificName    CommonName  Status  EstimatedCover  \
# 0       NaN                 NaN           NaN     NaN             0.0
# 1       NaN                 NaN           NaN     NaN            40.0
# 2      live            Atriplex      saltbush     NaN            40.0
# 3      live  Distichlis spicata     Saltgrass     NaN            20.0
# 4      live    Frankenia salina  Alkali heath     NaN            10.0
#
#    PercentCoverCode  DaubenmireMidpoint  TallestPlantHeight_cm  \
# 0               NaN                 NaN                    NaN
# 1               NaN                 NaN                    NaN
# 2               NaN                 NaN                   30.0
# 3               NaN                 NaN                    NaN
# 4               NaN                 NaN                   10.0
#
#   PercentCoverNotes
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# The epifauna data gives the number of invertebrates or invertebrate burrows (crab burrows, coffee bean snail, horn snail,
# ribbed mussel, pachygrapsus burrows, etc.) observed within each plot. The count is in the EnteredAbundance column. Sometimes subsampling is used. The abundance per m2 is in the EstimatedAbundance column.

# %%
## Look at epifauna data

veg_epi.head()
# Out:
#   SiteID    EstuaryName  StationNo SampleCollectionDate Habitat elevation  \
# 0    NaN  Goleta Slough          1           2021-03-23               mid
# 1    NaN  Goleta Slough          1           2021-03-23               mid
# 2    NaN  Goleta Slough          1           2021-03-23               mid
# 3    NaN  Goleta Slough          1           2021-03-23               mid
# 4    NaN  Goleta Slough          1           2021-03-23               mid
#
#    TransectReplicate  PlotReplicate      ScientificName          CommonName  \
# 0                  1              1        crab burrows        crab burrows
# 1                  1              2  Melampus olivaceus  coffee  bean snail
# 2                  1              3                none                 NaN
# 3                  1              4  Melampus olivaceus  coffee  bean snail
# 4                  1              5                none                 NaN
#
#   Entered Abundance measured quadrat size (0.25*4 = 1) Estimated Abundance
# 0                 1                             0.25 m                   4
# 1               NaN                             0.25 m                   0
# 2                 0                             0.25 m                   0
# 3                 1                             0.25 m                   4
# 4                 0                             0.25 m                   0

# %% [markdown]
# ## Fish Seines
#
# Righ now the sample metadata doesn't add a lot of information. Just whether the tide was going in or out, and whether the survey used seines or cast nets. Most of the other columns are empty.

# %%
## Look at sample metadata

fish_sample.head()
# Out:
#    SiteID    EstuaryName  StationNo SampleCollectionDate Weather      Tide  \
# 0  SC-GOL  Goleta Slough          1           2021-03-24     NaN  outgoing
# 1  SC-GOL  Goleta Slough          1           2021-03-24     NaN  outgoing
# 2  SC-GOL  Goleta Slough          1           2021-03-24     NaN  outgoing
# 3  SC-GOL  Goleta Slough          2           2021-03-23     NaN  outgoing
# 4  SC-GOL  Goleta Slough          2           2021-03-23     NaN  outgoing
#
#    SurveyType  NetReplicate  Depth_m  Substrate  ...  EndTime  \
# 0  fish seine             1      NaN        NaN  ...      NaN
# 1  fish seine             2      NaN        NaN  ...      NaN
# 2  fish seine             3      NaN        NaN  ...      NaN
# 3  fish seine             1      NaN        NaN  ...      NaN
# 4  fish seine             2      NaN        NaN  ...      NaN
#
#    SeineMeshSize_mm  SeineLength_m  SeineHeight_m SeineDistance_m  Area_m2  \
# 0               NaN            NaN            NaN             NaN      NaN
# 1               NaN            NaN            NaN             NaN      NaN
# 2               NaN            NaN            NaN             NaN      NaN
# 3               NaN            NaN            NaN             NaN      NaN
# 4               NaN            NaN            NaN             NaN      NaN
#
#    SAVPresent                  DataCollector  DataEntryPerson  \
# 0          no  Kyra, Anita, David, Sebastian       Jan Walker
# 1          no  Kyra, Anita, David, Sebastian       Jan Walker
# 2          no  Kyra, Anita, David, Sebastian       Jan Walker
# 3          no                            NaN       Jan Walker
# 4          no                            NaN       Jan Walker
#
#                                  SampleMetadataNotes
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  high abundance of Ulva sp. and cerithidea pres...
# 4                                                NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# The abundance data contains the common name and number of each fish caught during each survey. If no fish were caught, a row has been entered where the abundance is 0 and the common name is missing. Almost no scientific names are currently included.
#
# Note that sometimes invertebrates were also caught and their abundance recorded.

# %%
## Look at abundance data

fish_abundance.head()
# Out:
#    SiteID    EstuaryName  StationNo SampleCollectionDate  SurveyType  \
# 0  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
# 1  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
# 2  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
# 3  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
# 4  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
#
#    NetReplicate ScientificName        CommonName  IdentificationNotes  \
# 0             1            NaN  Staghorn sculpin                  NaN
# 1             1            NaN        arrow goby                  NaN
# 2             2            NaN  Staghorn sculpin                  NaN
# 3             2            NaN         top smelt                  NaN
# 4             2            NaN        Killy fish                  NaN
#
#    Abundance  AbundanceNotes
# 0          5             NaN
# 1          2             NaN
# 2         17             NaN
# 3         11             NaN
# 4          1             NaN

# %% [markdown]
# The length data contains the size in mm of each fish caught. If a lot of fish were caught, sometimes only a subset was measured.
#
# ```python
# num_caught = fish_abundance.groupby(['EstuaryName', 'StationNo', 'SurveyType', 'NetReplicate'], as_index=False)['Abundance'].sum()
# num_caught[(num_caught['EstuaryName'] == 'Goleta Slough') & (num_caught['Abundance'] != 0)]
#
# num_measured = fish_length.groupby(['EstuaryName', 'StationNo', 'SurveyType', 'NetReplicate'], as_index=False)['CommonName'].count()
# num_measured[num_measured['EstuaryName'] == 'Goleta Slough']
# ```
#
# Note that sometimes invertebrates were also caught and their size recorded. Which measurement was taken is included in the LengthNotes.

# %%
## Look at length data

fish_length.head()
# Out:
#    SiteID    EstuaryName  StationNo SampleCollectionDate  SurveyType  \
# 0  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
# 1  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
# 2  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
# 3  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
# 4  SC-GOL  Goleta Slough          1           2021-03-24  fish seine
#
#    NetReplicate ScientificName        CommonName  IdentificationNotes  \
# 0             1            NaN  Staghorn sculpin                  NaN
# 1             1            NaN  Staghorn sculpin                  NaN
# 2             1            NaN  Staghorn sculpin                  NaN
# 3             1            NaN  Staghorn sculpin                  NaN
# 4             1            NaN  Staghorn sculpin                  NaN
#
#    Length_mm LengthNotes
# 0        7.2         NaN
# 1        2.2         NaN
# 2        3.1         NaN
# 3        2.2         NaN
# 4        2.5         NaN
